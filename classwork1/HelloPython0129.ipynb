# %% [markdown]
# Hello Python! This is my very first notebook

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Any String!")
# Out:
# Any String!

# %%
print(5)
# Out:
# 5

# %%
print(5+10)
# Out:
# 15

# %%
print(True)
# Out:
# True

# %%
print("Hello Class!")
print("TACC's awesome")
print("Indoctrination, yay!")
# Out:
# Hello Class!
# TACC's awesome
# Indoctrination, yay!

# %%
print("hello world")
# Out:
# hello world

# %%
2.3+5.5
# Out:
# 7.8

# %%
name = "Charlie"
NAME = "Alex"

# %%
print(name)
# Out:
# Charlie

# %%
print(NAME)
# Out:
# Alex

# %%
num1 = 5
num2 = 7.0

# %%
a = "Hello"
b = True

# %%
type(a)
# Out:
# str

# %%
type(b)
# Out:
# bool

# %%
type(num1)
# Out:
# int

# %%
type(num2)
# Out:
# int

# %%
type(num2)
# Out:
# int

# %%
type(num2)
# Out:
# float

# %%
string1 = str(num2)

# %%
print(string1)
print(type(string1))
# Out:
# 7.0
# <class 'str'>

# %%
2**3
# Out:
# 8

# %%
num4 = 2**3

# %%
print(num4)
# Out:
# 8

# %%
type(num4)
# Out:
# int

# %%
number1 = 5.0/2
number2 = 5/2
print(number1)
print(number2)
# Out:
# 2.5
# 2.5

# %%
numIn = input("Enter a number:")
# Out:
# Enter a number: 5

# %%
print(type(numIn))
# Out:
# <class 'str'>

# %%
num6 = 5%2

# %%
print(num6)
# Out:
# 1

# %%
myfile = open("test.dat", 'w')
myfile.write(numIn)
myfile.write("\n")
myfile.write("Hello World \n")
myfile.close()

# %%
myfile2 = open("test.dat", 'r')
content = myfile2.read()
myfile2.close()
print(content)
# Out:
# 5
# Hello World

# %%
a = 2
b = 5

# %%
print(a>b)
# Out:
# False

# %%
print(b>a)
# Out:
# True

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 print(b=a)
#
# TypeError: print() got an unexpected keyword argument 'b'

# %%
print(a = b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 print(a = b)
#
# TypeError: print() got an unexpected keyword argument 'a'

# %%
print(b==a or b<a)
# Out:
# False

# %%
print(b==a)
# Out:
# False

# %%
if(a>b): print("A is greater than B")

# %%
if(a<b): print("B is greater than A")
# Out:
# B is greater than A

# %%
if (b<a):
    print("Be is less than A")
    print("Conditionals are awesome!")
print("All done!")
# Out:
# All done!

# %%
if (b>a):
    print("Be is greater than A")
    print("Conditionals are awesome!")
print("All done!")
# Out:
# Be is greater than A
# Conditionals are awesome!
# All done!

# %%
for r in range(1,3):
    print(r, r**2)
# Out:
# 1 1
# 2 4

# %%
for r in range(1,4):
    print(r,r**2)
# Out:
# 1 1
# 2 4
# 3 9

# %%
for i in range(1,4):
    for j in range (2,7):
        print(i,j)
# Out:
# 1 2
# 1 3
# 1 4
# 1 5
# 1 6
# 2 2
# 2 3
# 2 4
# 2 5
# 2 6
# 3 2
# 3 3
# 3 4
# 3 5
# 3 6

# %%
mylist = ["Prasun", 10, "blue", 7, "Alex", 9, "black", 21]

# %%
for t in mylist:
    print(t, type(t))
# Out:
# Prasun <class 'str'>
# 10 <class 'int'>
# blue <class 'str'>
# 7 <class 'int'>
# Alex <class 'str'>
# 9 <class 'int'>
# black <class 'str'>
# 21 <class 'int'>

# %%
print(mylist)
# Out:
# ['Prasun', 10, 'blue', 7, 'Alex', 9, 'black', 21]

# %%
print(mylist[3:6])
# Out:
# [7, 'Alex', 9]

# %%
print("43" in mylist)
# Out:
# False

# %%
import math

def calc_hyp(a, b):
    h = math.sqrt(a*a + b*b)
    return h

# %%
my_h = calc_hyp(3,4)
print(my_h)
# Out:
# 5.0
